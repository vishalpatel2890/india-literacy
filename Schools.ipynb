# %%
import pandas as pd
import numpy as np

# %%
from tabula import read_pdf

# %%
schools_df = read_pdf("ESAG-2018.pdf", pages=63,pandas_options = {'header': 2})

# %%
schools_df
# Out:
#      No.                 Unnamed: 1  2013-14  2014-15  2015-16  2013-14.1  \
# 0    1.0  Andaman & Nicobar Islands      273      223      218         76
# 1    2.0             Andhra Pradesh    66222    40703    38793      16992
# 2    3.0          Arunachal Pradesh     2363     2341     2363       1144
# 3    4.0                      Assam    47947    48478    48529      13065
# 4    5.0                      Bihar    42525    43223    43405      32069
# 5    6.0                 Chandigarh       11       11       12         26
# 6    7.0               Chhattisgarh    35325    35149    32826      15008
# 7    8.0       Dadra & Nagar Haveli      181      176      177        122
# 8    9.0                Daman & Diu       55       60       59         29
# 9   10.0                      Delhi     2678     2776     2755        710
# 10  11.0                        Goa     1023      988      973         76
# 11  12.0                    Gujarat    11698    11689    11840      28918
# ...

# %%
schools_df.rename(columns={'Unnamed: 1':'State'})
# Out:
#      No.                      State  2013-14  2014-15  2015-16  2013-14.1  \
# 0    1.0  Andaman & Nicobar Islands      273      223      218         76
# 1    2.0             Andhra Pradesh    66222    40703    38793      16992
# 2    3.0          Arunachal Pradesh     2363     2341     2363       1144
# 3    4.0                      Assam    47947    48478    48529      13065
# 4    5.0                      Bihar    42525    43223    43405      32069
# 5    6.0                 Chandigarh       11       11       12         26
# 6    7.0               Chhattisgarh    35325    35149    32826      15008
# 7    8.0       Dadra & Nagar Haveli      181      176      177        122
# 8    9.0                Daman & Diu       55       60       59         29
# 9   10.0                      Delhi     2678     2776     2755        710
# 10  11.0                        Goa     1023      988      973         76
# 11  12.0                    Gujarat    11698    11689    11840      28918
# ...

# %%
schools_df = schools_df.rename(columns={'Unnamed: 1':'State'})

# %%
schools_df
# Out:
#      No.                      State  2013-14  2014-15  2015-16  2013-14.1  \
# 0    1.0  Andaman & Nicobar Islands      273      223      218         76
# 1    2.0             Andhra Pradesh    66222    40703    38793      16992
# 2    3.0          Arunachal Pradesh     2363     2341     2363       1144
# 3    4.0                      Assam    47947    48478    48529      13065
# 4    5.0                      Bihar    42525    43223    43405      32069
# 5    6.0                 Chandigarh       11       11       12         26
# 6    7.0               Chhattisgarh    35325    35149    32826      15008
# 7    8.0       Dadra & Nagar Haveli      181      176      177        122
# 8    9.0                Daman & Diu       55       60       59         29
# 9   10.0                      Delhi     2678     2776     2755        710
# 10  11.0                        Goa     1023      988      973         76
# 11  12.0                    Gujarat    11698    11689    11840      28918
# ...

# %%
schools_df.drop(columns='No.', axis = 1)
# Out:
#                         State  2013-14  2014-15  2015-16  2013-14.1  \
# 0   Andaman & Nicobar Islands      273      223      218         76
# 1              Andhra Pradesh    66222    40703    38793      16992
# 2           Arunachal Pradesh     2363     2341     2363       1144
# 3                       Assam    47947    48478    48529      13065
# 4                       Bihar    42525    43223    43405      32069
# 5                  Chandigarh       11       11       12         26
# 6                Chhattisgarh    35325    35149    32826      15008
# 7        Dadra & Nagar Haveli      181      176      177        122
# 8                 Daman & Diu       55       60       59         29
# 9                       Delhi     2678     2776     2755        710
# 10                        Goa     1023      988      973         76
# 11                    Gujarat    11698    11689    11840      28918
# 12                    Haryana    10249     9849     9994       4358
# ...

# %%
schools_df = schools_df.drop(columns='No.', axis = 1)

# %%
schools_df = schools_df.drop(columns=['2013-14','2014-15','2013-14.1','2014-15.1','2015-16.1'], axis=1)

# %%
schools_df
# Out:
#                         State  2015-16
# 0   Andaman & Nicobar Islands      218
# 1              Andhra Pradesh    38793
# 2           Arunachal Pradesh     2363
# 3                       Assam    48529
# 4                       Bihar    43405
# 5                  Chandigarh       12
# 6                Chhattisgarh    32826
# 7        Dadra & Nagar Haveli      177
# 8                 Daman & Diu       59
# 9                       Delhi     2755
# 10                        Goa      973
# 11                    Gujarat    11840
# 12                    Haryana     9994
# 13           Himachal Pradesh    11327
# 14          Jammu and Kashmir    14604
# 15                  Jharkhand    28010
# 16                  Karnataka    26790
# 17                     Kerala     8428
# 18                Lakshadweep       17
# 19             Madhya Pradesh    88593
# 20                Maharashtra    53151
# 21                    Manipur     2951
# 22                  Meghalaya     9362
# ...
