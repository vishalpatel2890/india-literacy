# %%
import os 
import pandas as pd
import numpy as np

# %%
pd.read_csv('india-districts-census-2011.csv')
# Out:
#      District code                   State Name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# 5                6            JAMMU AND KASHMIR                    Rajouri
# 6                7            JAMMU AND KASHMIR                     Kathua
# 7                8            JAMMU AND KASHMIR                   Baramula
# 8                9            JAMMU AND KASHMIR                  Bandipore
# 9               10            JAMMU AND KASHMIR                   Srinagar
# 10              11            JAMMU AND KASHMIR                  Ganderbal
# ...

# %%
df = pd.read_csv('india-districts-census-2011.csv', usecols=list(range(1,9)) + list(range(36,40)) + list(range(117,118)))

# %%
df.head()
# Out:
#           State Name District name  Population    Male  Female  Literate  \
# 0  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654
# 1  JAMMU AND KASHMIR        Badgam      753745  398041  355704    335649
# 2  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516     93770
# 3  JAMMU AND KASHMIR        Kargil      140802   77785   63017     86236
# 4  JAMMU AND KASHMIR         Punch      476835  251899  224936    261724
#
#    Male_Literate  Female_Literate  Households_with_Computer  Rural_Households  \
# 0         282823           156831                      5256            158438
# 1         207741           127908                      5892            160649
# 2          62834            30936                      2150             36920
# 3          56301            29935                      1005             40370
# 4         163333            98391                      3342            132139
#
#    Urban_Households  Households  Total_Power_Parity
# ...

# %%
df['M/F Ratio'] = df['Male']/df['Female']

# %%
df.head()
# Out:
#           State Name District name  Population    Male  Female  Literate  \
# 0  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654
# 1  JAMMU AND KASHMIR        Badgam      753745  398041  355704    335649
# 2  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516     93770
# 3  JAMMU AND KASHMIR        Kargil      140802   77785   63017     86236
# 4  JAMMU AND KASHMIR         Punch      476835  251899  224936    261724
#
#    Male_Literate  Female_Literate  Households_with_Computer  Rural_Households  \
# 0         282823           156831                      5256            158438
# 1         207741           127908                      5892            160649
# 2          62834            30936                      2150             36920
# 3          56301            29935                      1005             40370
# 4         163333            98391                      3342            132139
#
# ...

# %%
df['Literacy_Ratio'] = df['Literate']/df['Population']

# %%
df.head()
# Out:
#           State Name District name  Population    Male  Female  Literate  \
# 0  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654
# 1  JAMMU AND KASHMIR        Badgam      753745  398041  355704    335649
# 2  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516     93770
# 3  JAMMU AND KASHMIR        Kargil      140802   77785   63017     86236
# 4  JAMMU AND KASHMIR         Punch      476835  251899  224936    261724
#
#    Male_Literate  Female_Literate  Households_with_Computer  Rural_Households  \
# 0         282823           156831                      5256            158438
# 1         207741           127908                      5892            160649
# 2          62834            30936                      2150             36920
# 3          56301            29935                      1005             40370
# 4         163333            98391                      3342            132139
#
# ...

# %%
df['%_Households_With_Computers'] = df['Households_with_Computer']/df['Households']

# %%
df.head()
# Out:
#           State Name District name  Population    Male  Female  Literate  \
# 0  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654
# 1  JAMMU AND KASHMIR        Badgam      753745  398041  355704    335649
# 2  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516     93770
# 3  JAMMU AND KASHMIR        Kargil      140802   77785   63017     86236
# 4  JAMMU AND KASHMIR         Punch      476835  251899  224936    261724
#
#    Male_Literate  Female_Literate  Households_with_Computer  Rural_Households  \
# 0         282823           156831                      5256            158438
# 1         207741           127908                      5892            160649
# 2          62834            30936                      2150             36920
# 3          56301            29935                      1005             40370
# 4         163333            98391                      3342            132139
#
# ...

# %%
df['%_of_Urban_Households'] = df['Urban_Households']/df['Households']

# %%
df.head()
# Out:
#           State Name District name  Population    Male  Female  Literate  \
# 0  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654
# 1  JAMMU AND KASHMIR        Badgam      753745  398041  355704    335649
# 2  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516     93770
# 3  JAMMU AND KASHMIR        Kargil      140802   77785   63017     86236
# 4  JAMMU AND KASHMIR         Punch      476835  251899  224936    261724
#
#    Male_Literate  Female_Literate  Households_with_Computer  Rural_Households  \
# 0         282823           156831                      5256            158438
# 1         207741           127908                      5892            160649
# 2          62834            30936                      2150             36920
# 3          56301            29935                      1005             40370
# 4         163333            98391                      3342            132139
#
# ...

# %%
census_df = df.groupby('State Name').mean()

# %%
census_df
# Out:
#                                Population          Male        Female  \
# State Name
# ANDAMAN AND NICOBAR ISLANDS  1.268603e+05  6.762367e+04  5.923667e+04
# ANDHRA PRADESH               3.677425e+06  1.845311e+06  1.832114e+06
# ARUNACHAL PRADESH            8.648294e+04  4.461950e+04  4.186344e+04
# ASSAM                        1.155762e+06  5.903497e+05  5.654123e+05
# BIHAR                        2.739459e+06  1.428373e+06  1.311087e+06
# CHANDIGARH                   1.055450e+06  5.806630e+05  4.747870e+05
# CHHATTISGARH                 1.419178e+06  7.129386e+05  7.062391e+05
# DADRA AND NAGAR HAVELI       3.437090e+05  1.937600e+05  1.499490e+05
# DAMAN AND DIU                1.216235e+05  7.515050e+04  4.647300e+04
# GOA                          7.292725e+05  3.695700e+05  3.597025e+05
# GUJARAT                      2.324604e+06  1.211202e+06  1.113401e+06
# HARYANA                      1.207212e+06  6.426064e+05  5.646061e+05
# ...

# %%
data = df.iloc[:,:-5]

target = df['Total Literacy Rate']
